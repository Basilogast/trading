# %%
import sys
sys.path.append(r"e:/work/IT/trading/MyCode/FindingBacktest")  # Add the directory to the Python path

from FindingTrade import FindingTradeEMA

# %%
trader = FindingTradeEMA("oanda.cfg", "EUR_USD", "1min", units=100000, ema_s=12, ema_l=26)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 trader = FindingTradeEMA("oanda.cfg", "EUR_USD", "1min", units=100000)
#
# TypeError: FindingTradeEMA.__init__() missing 2 required positional arguments: 'ema_s' and 'ema_l'
