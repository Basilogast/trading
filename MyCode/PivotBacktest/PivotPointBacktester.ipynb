# %%
import pandas as pd
import sys
sys.path.append(r"e:/work/IT/trading/MyCode/PivotBacktest")  # Add the directory to the Python path

from PivotPointBacktester import PivotPointBacktester  # Import the class

# %%
filepath = "./data/one_minute.csv"  # Updated to correct relative path
symbol = "GBPUSD"

start1 = "2018-01-01"
end1 = "2018-03-31"
start2 = "2018-04-01"
end2 = "2018-06-30"
start3 = "2018-07-01"
end3 = "2018-09-30"
start4 = "2018-10-01"
end4 = "2018-12-31"

end5 = "2019-06-30"

ptc = 0.00007

# %% [markdown]
# __1. Quarter 2018__

# %%
tester = PivotPointBacktester(filepath = filepath, symbol = symbol, start = start1, end = end1, tc = ptc)
tester

# %%
tester.download_recent_data("EUR_USD", 100000, "EUR_recent_data_1.csv")

# %%
tester.download_recent_data("GBP_USD", 100000, "GBP_recent_data_1.csv")

# %%
tester.prepare_data()

# %%
tester.test_strategy()

# %%
tester.results

# %%
tester.add_leverage(10)

# %%
tester.results

# %%
import matplotlib.pyplot as plt
plt.style.use("seaborn-v0_8")

# %%
tester.results[["creturns", "cstrategy", "cstrategy_net"]].plot(figsize = (12 , 8))
plt.show()

# %%
tester.optimize_strategy((51, 301, 5), (51,301, 5), (2, 4, 1), metric = "Multiple") # keep dev constant (2)

# %% [markdown]
# __Iterative Testing__

# %%
import pandas as pd
import sys
sys.path.append(r"e:/work/IT/trading/MyCode/PivotBacktest")  # Add the directory to the Python path

from PivotPointBacktester import PivotPointBacktester  # Import the class

# %%
import sys
sys.path.append(r"../../MyCode/PivotBacktest")  # Add the relative path to the Python path
import IterativeBacktest as IB

# %%
filepath = "./data/GBP_recent_data_1.csv"  # Updated to correct relative path
symbol = "GBPUSD"

start1 = "2018-01-01"
end1 = "2018-03-31"
start2 = "2018-04-01"
end2 = "2018-06-30"
start3 = "2018-07-01"
end3 = "2018-09-30"
start4 = "2018-10-01"
end4 = "2018-12-31"

end5 = "2019-06-30"

ptc = 0.00007

# %%
bc = IB.IterativeBacktest(symbol, "2025-03-14", "2025-06-20", 100000, file_path=filepath, use_spread = True)
# Out:
# Loading data from: ./data/GBP_recent_data_1.csv
# Date range: 2025-03-14 to 2025-06-20
# Data loaded. Total rows before filtering: 99999
# Total rows after filtering by date range: 83760
# Data successfully loaded and processed.

# %%
bc.data
# Out:
#                         price     Open     High      Low    Close   spread  \
# time
# 2025-04-01 05:28:00  1.292440  1.29240  1.29253  1.29240  1.29248  0.00021
# 2025-04-01 05:29:00  1.292490  1.29247  1.29252  1.29240  1.29251  0.00020
# 2025-04-01 05:30:00  1.292505  1.29252  1.29258  1.29248  1.29249  0.00018
# 2025-04-01 05:31:00  1.292470  1.29246  1.29250  1.29244  1.29248  0.00018
# 2025-04-01 05:32:00  1.292475  1.29246  1.29253  1.29244  1.29249  0.00020
# ...                       ...      ...      ...      ...      ...      ...
# 2025-06-20 20:55:00  1.344860  1.34488  1.34494  1.34480  1.34484  0.00030
# 2025-06-20 20:56:00  1.344815  1.34486  1.34486  1.34468  1.34477  0.00040
# 2025-06-20 20:57:00  1.344815  1.34476  1.34487  1.34468  1.34487  0.00040
# 2025-06-20 20:58:00  1.344920  1.34488  1.34517  1.34487  1.34496  0.00041
# 2025-06-20 20:59:00  1.344970  1.34500  1.34500  1.34494  1.34494  0.00089
#
#                       returns
# time
# ...

# %%
bc.test_pivot_strategy()
# Out:
# ---------------------------------------------------------------------------
# Testing Pivot Point Strategy | GBPUSD
# ---------------------------------------------------------------------------
# Loading data from: ./data/GBP_recent_data_1.csv
# Date range: 2025-03-14 to 2025-06-20
# Data loaded. Total rows before filtering: 99999
# Total rows after filtering by date range: 83760
# Data successfully loaded and processed.
# 2025-04-01 |  Buying 7736 for 1.29254
# 2025-04-01 |  Selling 7736 for 1.29164
# 2025-04-01 |  Selling 7742 for 1.29164
# 2025-04-01 |  Buying 7742 for 1.29129
# 2025-04-01 |  Buying 7744 for 1.29129
# 2025-04-01 |  Selling 7744 for 1.2912
# 2025-04-01 |  Selling 7744 for 1.2912
# 2025-04-01 |  Buying 7744 for 1.29163
# 2025-04-01 |  Buying 7742 for 1.29163
# 2025-04-01 |  Selling 7742 for 1.29188
# 2025-04-01 |  Selling 7740 for 1.29188
# 2025-04-01 |  Buying 7740 for 1.29062
# 2025-04-01 |  Buying 7748 for 1.29062
# 2025-04-01 |  Selling 7748 for 1.29083
# ...
